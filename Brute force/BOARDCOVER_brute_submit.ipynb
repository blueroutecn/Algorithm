# %%
for i in range(0,3):
    for j in range(0,2):
        print('hel')
        print(i,j)
        if i == 1:            
            i = 3
            j = 2
            break

# %%
def CheckBoard(fw,Matrix):
    
    """
    모두 막혀져 있는 문제도 체크해야하나?    
    """
    H = len(Matrix)
    W = len(Matrix[0])
    for i in range(0,H):
        fw.writelines('{} \n'.format(Matrix[i][0:]))  
    fw.write('=='*20 + '\n')
        
    nempty = 0
    for line in Matrix:
        for i in line:
            if i == 1:
                nempty = nempty + 1
    fw.write('nempty: {}'.format(nempty) + '\n')
    if nempty == 0:              
        return 1
    
    if nempty < 3:
        return 0
    
    flag = False
    for i in range(0,H):
        for j in range(0,W):
            if Matrix[i][j] == 1:
                y = i
                x = j
                flag = True
                break
                fw.write('x: {}, y: {}'.format(x,y) + '\n')
        if flag:
            break
                
    ret = 0

    hidx = [y,y,y+1]
    widx = [x,x+1,x]                        
    htmp = [idx for idx,item in enumerate(hidx) if not (item>=0 and item <H)]
    wtmp = [idx for idx,item in enumerate(widx) if not (item>=0 and item <W)]            
    if not htmp and not wtmp:
        if Matrix[hidx[0]][widx[0]] == 1 \
        and Matrix[hidx[1]][widx[1]] == 1\
        and Matrix[hidx[2]][widx[2]] == 1:
            fw.write('{}'.format(hidx))
            fw.write('{}'.format(widx))
            fw.write('type1\n')
            Matrix[hidx[0]][widx[0]] = 0
            Matrix[hidx[1]][widx[1]] = 0
            Matrix[hidx[2]][widx[2]] = 0
            ret += CheckBoard(fw,Matrix)
            Matrix[hidx[0]][widx[0]] = 1
            Matrix[hidx[1]][widx[1]] = 1
            Matrix[hidx[2]][widx[2]] = 1

    hidx = [y,y,y+1]
    widx = [x,x+1,x+1]                        
    htmp = [idx for idx,item in enumerate(hidx) if not (item>=0 and item <H)]
    wtmp = [idx for idx,item in enumerate(widx) if not (item>=0 and item <W)]            
    if not htmp and not wtmp:
        if Matrix[hidx[0]][widx[0]] == 1 \
        and Matrix[hidx[1]][widx[1]] == 1\
        and Matrix[hidx[2]][widx[2]] == 1:
            fw.write('{}'.format(hidx))
            fw.write('{}'.format(widx))
            fw.write('type2\n')
            Matrix[hidx[0]][widx[0]] = 0
            Matrix[hidx[1]][widx[1]] = 0
            Matrix[hidx[2]][widx[2]] = 0
            ret += CheckBoard(fw,Matrix)
            Matrix[hidx[0]][widx[0]] = 1
            Matrix[hidx[1]][widx[1]] = 1
            Matrix[hidx[2]][widx[2]] = 1

    hidx = [y,y+1,y+1]
    widx = [x,x,x+1]                        
    htmp = [idx for idx,item in enumerate(hidx) if not (item>=0 and item <H)]
    wtmp = [idx for idx,item in enumerate(widx) if not (item>=0 and item <W)]            
    if not htmp and not wtmp:
        if Matrix[hidx[0]][widx[0]] == 1 \
        and Matrix[hidx[1]][widx[1]] == 1\
        and Matrix[hidx[2]][widx[2]] == 1:
            fw.write('{}'.format(hidx))
            fw.write('{}'.format(hidx))
            fw.write('{}'.format(widx))
            fw.write('type3\n')
            Matrix[hidx[0]][widx[0]] = 0
            Matrix[hidx[1]][widx[1]] = 0
            Matrix[hidx[2]][widx[2]] = 0
            ret += CheckBoard(fw,Matrix)
            Matrix[hidx[0]][widx[0]] = 1
            Matrix[hidx[1]][widx[1]] = 1
            Matrix[hidx[2]][widx[2]] = 1


    hidx = [y,y+1,y+1]
    widx = [x,x,x-1]                        
    htmp = [idx for idx,item in enumerate(hidx) if not (item>=0 and item <H)]
    wtmp = [idx for idx,item in enumerate(widx) if not (item>=0 and item <W)]            
    if not htmp and not wtmp:
        if Matrix[hidx[0]][widx[0]] == 1 \
        and Matrix[hidx[1]][widx[1]] == 1\
        and Matrix[hidx[2]][widx[2]] == 1:
            fw.write('{}'.format(hidx))
            fw.write('{}'.format(widx))
            fw.write('type4\n')
            Matrix[hidx[0]][widx[0]] = 0
            Matrix[hidx[1]][widx[1]] = 0
            Matrix[hidx[2]][widx[2]] = 0
            ret += CheckBoard(fw,Matrix)
            Matrix[hidx[0]][widx[0]] = 1
            Matrix[hidx[1]][widx[1]] = 1
            Matrix[hidx[2]][widx[2]] = 1
      
    return ret

# %%
f = open('BOARDCOVER.txt', 'r')
fw = open('BOARDCOVER_answer.txt', 'w')
idx = 0
n = int(f.readline())
while idx < n:
    tmp = f.readline().split()
    H = int(tmp[0])
    W = int(tmp[1])
    block = ''
    for i in range(H):
        tmp = f.readline().strip()                
        block = block + tmp 
    Matrix = [[0]*W for i in range(H)]
    for i in range(0,len(block)):
        ch = block[i]
        if ch == '.':
            widx = i%W
            hidx = int(i/W)
            Matrix[hidx][widx] = 1
        elif ch == '#':
            widx = i%W
            hidx = int(i/W)
            Matrix[hidx][widx] = 0
    for i in range(0,H):
        fw.writelines('{} \n'.format(Matrix[i][0:]))  
        
    fw.write('=='*20 + '\n')
    ret = CheckBoard(fw,Matrix)
    print(ret)
    idx = idx + 1    
fw.close()
f.close()
# Out:
# 0
# 2
# 1514

# %%
def CheckBoard(Matrix):
    
    """
    모두 막혀져 있는 문제도 체크해야하나?    
    """
    H = len(Matrix)
    W = len(Matrix[0])

        
    nempty = 0
    for line in Matrix:
        for i in line:
            if i == 1:
                nempty = nempty + 1
    if nempty == 0:              
        return 1
    
    if nempty < 3:
        return 0
    
    flag = False
    for i in range(0,H):
        for j in range(0,W):
            if Matrix[i][j] == 1:
                y = i
                x = j
                flag = True
                break
        if flag:
            break
                
    ret = 0

    hidx = [y,y,y+1]
    widx = [x,x+1,x]                        
    htmp = [idx for idx,item in enumerate(hidx) if not (item>=0 and item <H)]
    wtmp = [idx for idx,item in enumerate(widx) if not (item>=0 and item <W)]            
    if not htmp and not wtmp:
        if Matrix[hidx[0]][widx[0]] == 1 \
        and Matrix[hidx[1]][widx[1]] == 1\
        and Matrix[hidx[2]][widx[2]] == 1:

            Matrix[hidx[0]][widx[0]] = 0
            Matrix[hidx[1]][widx[1]] = 0
            Matrix[hidx[2]][widx[2]] = 0
            ret += CheckBoard(Matrix)
            Matrix[hidx[0]][widx[0]] = 1
            Matrix[hidx[1]][widx[1]] = 1
            Matrix[hidx[2]][widx[2]] = 1

    hidx = [y,y,y+1]
    widx = [x,x+1,x+1]                        
    htmp = [idx for idx,item in enumerate(hidx) if not (item>=0 and item <H)]
    wtmp = [idx for idx,item in enumerate(widx) if not (item>=0 and item <W)]            
    if not htmp and not wtmp:
        if Matrix[hidx[0]][widx[0]] == 1 \
        and Matrix[hidx[1]][widx[1]] == 1\
        and Matrix[hidx[2]][widx[2]] == 1:

            Matrix[hidx[0]][widx[0]] = 0
            Matrix[hidx[1]][widx[1]] = 0
            Matrix[hidx[2]][widx[2]] = 0
            ret += CheckBoard(Matrix)
            Matrix[hidx[0]][widx[0]] = 1
            Matrix[hidx[1]][widx[1]] = 1
            Matrix[hidx[2]][widx[2]] = 1

    hidx = [y,y+1,y+1]
    widx = [x,x,x+1]                        
    htmp = [idx for idx,item in enumerate(hidx) if not (item>=0 and item <H)]
    wtmp = [idx for idx,item in enumerate(widx) if not (item>=0 and item <W)]            
    if not htmp and not wtmp:
        if Matrix[hidx[0]][widx[0]] == 1 \
        and Matrix[hidx[1]][widx[1]] == 1\
        and Matrix[hidx[2]][widx[2]] == 1:

            Matrix[hidx[0]][widx[0]] = 0
            Matrix[hidx[1]][widx[1]] = 0
            Matrix[hidx[2]][widx[2]] = 0
            ret += CheckBoard(Matrix)
            Matrix[hidx[0]][widx[0]] = 1
            Matrix[hidx[1]][widx[1]] = 1
            Matrix[hidx[2]][widx[2]] = 1


    hidx = [y,y+1,y+1]
    widx = [x,x,x-1]                        
    htmp = [idx for idx,item in enumerate(hidx) if not (item>=0 and item <H)]
    wtmp = [idx for idx,item in enumerate(widx) if not (item>=0 and item <W)]            
    if not htmp and not wtmp:
        if Matrix[hidx[0]][widx[0]] == 1 \
        and Matrix[hidx[1]][widx[1]] == 1\
        and Matrix[hidx[2]][widx[2]] == 1:

            Matrix[hidx[0]][widx[0]] = 0
            Matrix[hidx[1]][widx[1]] = 0
            Matrix[hidx[2]][widx[2]] = 0
            ret += CheckBoard(Matrix)
            Matrix[hidx[0]][widx[0]] = 1
            Matrix[hidx[1]][widx[1]] = 1
            Matrix[hidx[2]][widx[2]] = 1
      
    return ret


f = open('BOARDCOVER.txt', 'r')
idx = 0
n = int(f.readline())
while idx < n:
    tmp = f.readline().split()
    H = int(tmp[0])
    W = int(tmp[1])
    block = ''
    for i in range(H):
        tmp = f.readline().strip()                
        block = block + tmp 
    Matrix = [[0]*W for i in range(H)]
    for i in range(0,len(block)):
        ch = block[i]
        if ch == '.':
            widx = i%W
            hidx = int(i/W)
            Matrix[hidx][widx] = 1
        elif ch == '#':
            widx = i%W
            hidx = int(i/W)
            Matrix[hidx][widx] = 0

        
    ret = CheckBoard(Matrix)
    print(ret)
    idx = idx + 1    
f.close()
# Out:
# 0
# 2
# 1514

# %%
def CheckBoard(Matrix):

    H = len(Matrix)
    W = len(Matrix[0])

        
    nempty = 0
    for line in Matrix:
        for i in line:
            if i == 1:
                nempty = nempty + 1
    if nempty == 0:              
        return 1
    
    if nempty < 3:
        return 0
    
    flag = False
    for i in range(0,H):
        for j in range(0,W):
            if Matrix[i][j] == 1:
                y = i
                x = j
                flag = True
                break
        if flag:
            break
                
    ret = 0

    hidx = [y,y,y+1]
    widx = [x,x+1,x]                        
    htmp = [idx for idx,item in enumerate(hidx) if not (item>=0 and item <H)]
    wtmp = [idx for idx,item in enumerate(widx) if not (item>=0 and item <W)]            
    if not htmp and not wtmp:
        if Matrix[hidx[0]][widx[0]] == 1 \
        and Matrix[hidx[1]][widx[1]] == 1\
        and Matrix[hidx[2]][widx[2]] == 1:

            Matrix[hidx[0]][widx[0]] = 0
            Matrix[hidx[1]][widx[1]] = 0
            Matrix[hidx[2]][widx[2]] = 0
            ret += CheckBoard(Matrix)
            Matrix[hidx[0]][widx[0]] = 1
            Matrix[hidx[1]][widx[1]] = 1
            Matrix[hidx[2]][widx[2]] = 1

    hidx = [y,y,y+1]
    widx = [x,x+1,x+1]                        
    htmp = [idx for idx,item in enumerate(hidx) if not (item>=0 and item <H)]
    wtmp = [idx for idx,item in enumerate(widx) if not (item>=0 and item <W)]            
    if not htmp and not wtmp:
        if Matrix[hidx[0]][widx[0]] == 1 \
        and Matrix[hidx[1]][widx[1]] == 1\
        and Matrix[hidx[2]][widx[2]] == 1:

            Matrix[hidx[0]][widx[0]] = 0
            Matrix[hidx[1]][widx[1]] = 0
            Matrix[hidx[2]][widx[2]] = 0
            ret += CheckBoard(Matrix)
            Matrix[hidx[0]][widx[0]] = 1
            Matrix[hidx[1]][widx[1]] = 1
            Matrix[hidx[2]][widx[2]] = 1

    hidx = [y,y+1,y+1]
    widx = [x,x,x+1]                        
    htmp = [idx for idx,item in enumerate(hidx) if not (item>=0 and item <H)]
    wtmp = [idx for idx,item in enumerate(widx) if not (item>=0 and item <W)]            
    if not htmp and not wtmp:
        if Matrix[hidx[0]][widx[0]] == 1 \
        and Matrix[hidx[1]][widx[1]] == 1\
        and Matrix[hidx[2]][widx[2]] == 1:

            Matrix[hidx[0]][widx[0]] = 0
            Matrix[hidx[1]][widx[1]] = 0
            Matrix[hidx[2]][widx[2]] = 0
            ret += CheckBoard(Matrix)
            Matrix[hidx[0]][widx[0]] = 1
            Matrix[hidx[1]][widx[1]] = 1
            Matrix[hidx[2]][widx[2]] = 1


    hidx = [y,y+1,y+1]
    widx = [x,x,x-1]                        
    htmp = [idx for idx,item in enumerate(hidx) if not (item>=0 and item <H)]
    wtmp = [idx for idx,item in enumerate(widx) if not (item>=0 and item <W)]            
    if not htmp and not wtmp:
        if Matrix[hidx[0]][widx[0]] == 1 \
        and Matrix[hidx[1]][widx[1]] == 1\
        and Matrix[hidx[2]][widx[2]] == 1:

            Matrix[hidx[0]][widx[0]] = 0
            Matrix[hidx[1]][widx[1]] = 0
            Matrix[hidx[2]][widx[2]] = 0
            ret += CheckBoard(Matrix)
            Matrix[hidx[0]][widx[0]] = 1
            Matrix[hidx[1]][widx[1]] = 1
            Matrix[hidx[2]][widx[2]] = 1
      
    return ret

import sys
rl = lambda: sys.stdin.readline()


idx = 0
n = int(rl())
while idx < n:
    tmp = rl().split()
    H = int(tmp[0])
    W = int(tmp[1])
    block = ''
    for i in range(H):
        tmp = rl().strip()                
        block = block + tmp 
    Matrix = [[0]*W for i in range(H)]
    for i in range(0,len(block)):
        ch = block[i]
        if ch == '.':
            widx = i%W
            hidx = int(i/W)
            Matrix[hidx][widx] = 1
        elif ch == '#':
            widx = i%W
            hidx = int(i/W)
            Matrix[hidx][widx] = 0

        
    ret = CheckBoard(Matrix)
    print(ret)
    idx = idx + 1    
f.close()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-be670f68ad2e> in <module>()
#      98 f = open('BOARDCOVER.txt', 'r')
#      99 idx = 0
# --> 100 n = int(rl())
#     101 while idx < n:
#     102     tmp = rl().split()
#
# ValueError: invalid literal for int() with base 10: ''
