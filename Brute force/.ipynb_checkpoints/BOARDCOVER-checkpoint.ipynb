# %%
def printblock(fw,block,H,W):
    for i in range(0,H):
        fw.write(block[W*i:W*(i+1)])
        fw.write('\n')
def CheckBoard(fw,block,H,W):
    """
    map 을 돌아다니면서 체크하고
    지도 업데이트 하고
    재귀 돌리고
    
    탈출조건은
    함수 시작할때 맵 꽉 차면 탈출하고
    
    리턴값은 맵 돌기 시작 직전에 ret = 0으로 셋팅하고
    
    리턴 ret 으로 함수 끝내고
    """
    if not ('.' in block):
        fw.write('you found one!'*5 + '\n')
        return 1
    
    ret = 0
    N = H*W
    for i in range(H):
        for j in range(W):
            
            idx = [W*i + j, W*i + j -1, W*(i-1) + j]            
            tmp = [item for item in idx if not (item>=0 and item <H*W)]                   
            if not tmp:
                
                tmp = block[idx[0]] + block[idx[1]] + block[idx[2]]                
                if tmp == '...':

                    block = block[0:idx[0]] + '#' + block[idx[0]+1:]
                    block = block[0:idx[1]] + '#' + block[idx[1]+1:]
                    block = block[0:idx[2]] + '#' + block[idx[2]+1:]                    
                    
                    ret += CheckBoard(fw,block,H,W)
                    
                    block = block[0:idx[0]] + '.' + block[idx[0]+1:]
                    block = block[0:idx[1]] + '.' + block[idx[1]+1:]
                    block = block[0:idx[2]] + '.' + block[idx[2]+1:]

                
            idx = [W*i + j, W*i + j + 1, W*(i-1) + j]            
            tmp = [item for item in idx if not (item>=0 and item <H*W)]            
            if not tmp:
                
                tmp = block[idx[0]] + block[idx[1]] + block[idx[2]]                
                if tmp == '...':

                    block = block[0:idx[0]] + '#' + block[idx[0]+1:]
                    block = block[0:idx[1]] + '#' + block[idx[1]+1:]
                    block = block[0:idx[2]] + '#' + block[idx[2]+1:]                    

                    
                    ret += CheckBoard(fw,block,H,W)
                    
                    block = block[0:idx[0]] + '.' + block[idx[0]+1:]
                    block = block[0:idx[1]] + '.' + block[idx[1]+1:]
                    block = block[0:idx[2]] + '.' + block[idx[2]+1:]

                
            idx = [W*i + j, W*i + j - 1, W*(i+1) + j]            
            tmp = [item for item in idx if not (item>=0 and item <H*W)]            
            if not tmp:
                
                tmp = block[idx[0]] + block[idx[1]] + block[idx[2]]                
                if tmp == '...':                    

                    block = block[0:idx[0]] + '#' + block[idx[0]+1:]
                    block = block[0:idx[1]] + '#' + block[idx[1]+1:]
                    block = block[0:idx[2]] + '#' + block[idx[2]+1:]                    

                    
                    ret += CheckBoard(fw,block,H,W)
                    
                    block = block[0:idx[0]] + '.' + block[idx[0]+1:]
                    block = block[0:idx[1]] + '.' + block[idx[1]+1:]
                    block = block[0:idx[2]] + '.' + block[idx[2]+1:]

                
            idx = [W*i + j, W*i + j + 1, W*(i+1) + j]            
            tmp = [item for item in idx if not (item>=0 and item <H*W)]            
            if not tmp:
                
                tmp = block[idx[0]] + block[idx[1]] + block[idx[2]]                
                if tmp == '...':

                    block = block[0:idx[0]] + '#' + block[idx[0]+1:]
                    block = block[0:idx[1]] + '#' + block[idx[1]+1:]
                    block = block[0:idx[2]] + '#' + block[idx[2]+1:]                    

                    ret += CheckBoard(fw,block,H,W)
                    
                    block = block[0:idx[0]] + '.' + block[idx[0]+1:]
                    block = block[0:idx[1]] + '.' + block[idx[1]+1:]
                    block = block[0:idx[2]] + '.' + block[idx[2]+1:]

            """
            check type1...4
            check each index > W or each index > H
            <type1>
            check H*i + W
            check H*i + W + 1
            check H*(i+1) + W
            """

    
    return ret

# %%
f = open('BOARDCOVER.txt', 'r')
fw = open('BOARDCOVER_answer.txt', 'w')
idx = 0
n = int(f.readline())
while idx < n:
    tmp = f.readline().split()
    H = int(tmp[0])
    W = int(tmp[1])
    block = ''
    for i in range(H):
        tmp = f.readline().strip()                
        block = block + tmp 
    n = int(block.count('.')/3)
    fact = 1
    for i in range(1,n+1):
        fact = fact * i
    ret = CheckBoard(fw,block,H,W)            
    
    ret = int(ret/fact)
    print(ret)
        
    idx = idx + 1    
fw.close()
f.close()

# %%
def CheckBoard(fw,block,H,W):
    if not ('.' in block):
        return 1
    
    ret = 0
    N = H*W
    for i in range(H):
        for j in range(W):
            
            idx = [W*i + j, W*i + j -1, W*(i-1) + j]            
            tmp = [item for item in idx if not (item>=0 and item <H*W)]                   
            if not tmp:
                
                tmp = block[idx[0]] + block[idx[1]] + block[idx[2]]                
                if tmp == '...':

                    block = block[0:idx[0]] + '#' + block[idx[0]+1:]
                    block = block[0:idx[1]] + '#' + block[idx[1]+1:]
                    block = block[0:idx[2]] + '#' + block[idx[2]+1:]                                        
                    ret += CheckBoard(fw,block,H,W)                    
                    block = block[0:idx[0]] + '.' + block[idx[0]+1:]
                    block = block[0:idx[1]] + '.' + block[idx[1]+1:]
                    block = block[0:idx[2]] + '.' + block[idx[2]+1:]
                
            idx = [W*i + j, W*i + j + 1, W*(i-1) + j]            
            tmp = [item for item in idx if not (item>=0 and item <H*W)]            
            if not tmp:
                
                tmp = block[idx[0]] + block[idx[1]] + block[idx[2]]                
                if tmp == '...':

                    block = block[0:idx[0]] + '#' + block[idx[0]+1:]
                    block = block[0:idx[1]] + '#' + block[idx[1]+1:]
                    block = block[0:idx[2]] + '#' + block[idx[2]+1:]                    
                    ret += CheckBoard(fw,block,H,W)                    
                    block = block[0:idx[0]] + '.' + block[idx[0]+1:]
                    block = block[0:idx[1]] + '.' + block[idx[1]+1:]
                    block = block[0:idx[2]] + '.' + block[idx[2]+1:]

                
            idx = [W*i + j, W*i + j - 1, W*(i+1) + j]            
            tmp = [item for item in idx if not (item>=0 and item <H*W)]            
            if not tmp:
                
                tmp = block[idx[0]] + block[idx[1]] + block[idx[2]]                
                if tmp == '...':                    

                    block = block[0:idx[0]] + '#' + block[idx[0]+1:]
                    block = block[0:idx[1]] + '#' + block[idx[1]+1:]
                    block = block[0:idx[2]] + '#' + block[idx[2]+1:]                    
                    ret += CheckBoard(fw,block,H,W)                    
                    block = block[0:idx[0]] + '.' + block[idx[0]+1:]
                    block = block[0:idx[1]] + '.' + block[idx[1]+1:]
                    block = block[0:idx[2]] + '.' + block[idx[2]+1:]

                
            idx = [W*i + j, W*i + j + 1, W*(i+1) + j]            
            tmp = [item for item in idx if not (item>=0 and item <H*W)]            
            if not tmp:
                
                tmp = block[idx[0]] + block[idx[1]] + block[idx[2]]                
                if tmp == '...':
                    
                    block = block[0:idx[0]] + '#' + block[idx[0]+1:]
                    block = block[0:idx[1]] + '#' + block[idx[1]+1:]
                    block = block[0:idx[2]] + '#' + block[idx[2]+1:]                                        
                    ret += CheckBoard(fw,block,H,W)                
                    block = block[0:idx[0]] + '.' + block[idx[0]+1:]
                    block = block[0:idx[1]] + '.' + block[idx[1]+1:]
                    block = block[0:idx[2]] + '.' + block[idx[2]+1:]    
    return ret

import sys
rl = lambda: sys.stdin.readline()
n = int(rl())

while idx < n:
    tmp = rl().split()
    H = int(tmp[0])
    W = int(tmp[1])
    block = ''
    for i in range(H):
        tmp = rl().strip()                
        block = block + tmp 
    n = int(block.count('.')/3)
    fact = 1
    for i in range(1,n+1):
        fact = fact * i
    ret = CheckBoard(fw,block,H,W)            
    ret = int(ret/fact)        
    idx = idx + 1
